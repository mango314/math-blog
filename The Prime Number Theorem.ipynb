# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
t = np.arange(0,0.5,10**(-5)) + 0.00001

a = np.sqrt(2)
b = np.sqrt(3)

f = lambda s: 2*np.floor(s**-1)-a*np.floor((a*s)**-1)-b*np.floor((b*s)**-1)

T = 20

plt.plot(t,(1.0/T)*f(t/T))
