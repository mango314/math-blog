# %% [markdown]
# # Refresher on Polynomials
#
# Don't remember why this project halted.  Got stuck computing zeros of polynomials of large degree
#
# http://scicomp.stackexchange.com/questions/18914/roots-of-polynomials-with-small-coefficients

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = 6,6

# %%
N = 1000
a = 0.5*(np.random.normal(0,1,N) + 1j*np.random.normal(0,1,N))

A = 1j*np.zeros((N,N))
A[:,-1] = a

x = np.arange(N-1)
A[x+1, x] =np.sqrt(x+1)

w = np.linalg.eigvals(A)
plt.plot(w.real, w.imag, '.', color="#BDFF28")

# %% [markdown]
# # Polynomials with Real Roots
#
# ---
#
# How many polynomials have real roots.  I noticed these two papers:
#
# * **Local universality of zeroes of random polynomials** http://arxiv.org/abs/1307.4357
# * **Universality for zeros of random analytic functions** http://arxiv.org/abs/1205.5355
#
# I first got interested in GAF and random models way back in 2007 when I went to Park City Math Institue -- I really enjoyed Utah!  In fact, my first paper on arXiv was on roots of polynomials
#
# A lot of these papers really miss the forest for the trees.  I think Tao-Vu's contribution is to show universality exists for coefficients that are not Gaussian or anything simple like that.  However, their discussion gets very technical...
#
# It might be best to refer to Kac's original paper, and Rice's discussion on Bell Labs:
#
# * On the average number of real roots of a random algebraic equation https://projecteuclid.org/euclid.bams/1183505112
# * A Mathmatical Analysis of Random Noise https://archive.org/details/bstj23-3-282
#
# Here's an example of random noise.  You have a great Html and CSS layout for your web-site, but you can't predict the size of the monitor of your user.  Nor can you tell which operating system (IOs, Android, Linux, Windows) they use or which Browser (Chrome 46, Firefox, IE 9, Opera) etc. or which device (Phone, Tablet, Computer).  With so much freedom, there's a lot of error with how your web-site gets rendered and there's not much you can do about it.
#
# Rice's theory of random noise may not be applicable, but just wanted to mention that.  Here is another approach which uses the **Crofton forumula** which may not be so good for algorithms:
#
# * How many zeros of a random polynomial are real? https://arxiv.org/abs/math/9501224
#
# Deterministic real coefficient polynomials could be studied using Descartes Rule of signs and I found a big literature on that.
#
# * http://www.stat.berkeley.edu/~pitman/621.pdf
# * http://statistics.berkeley.edu/sites/default/files/tech-reports/453.pdf
#
# These coefficients are not random... the coefficients themselves form a probability distribution.  So maybe I could do this as a separate project.
#
# I do recall a philosophical dilemma **where do random polynomials come from?** and despite all my reading I couldn't answer that and kind of moved on to the next thing.

# %%
# write about descartes rule of signs
