# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = 7,7

# %%
n = 1000

a = np.arange(n)
b = np.arange(n)

x = np.where((a[...,None]*b[None,...] +2 )% n == 0)



plt.xlim([-1,n+1])
plt.ylim([-1,n+1])

plt.xticks(np.arange(0, n+1, n/5))
plt.yticks(np.arange(0, n+1, n/5))

plt.plot(x[0], x[1], '.', markersize=4)

dt = 0.01
t  = np.arange(0,1+dt,dt)

z = 200j*t + (400+1000j)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 100*t + (600+1000j)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 400*t + (900+1000j)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 600*t + (1000+800j)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 800j*t + ( 100 + 1000j)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 900j*t + ( 200 + 1000j)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 200*t + (400j+1000)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 100j*t + (600j+1000)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 400j*t + (900j+1000)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 600j*t + (1000j+800)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 800*t + ( 100j + 1000)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 900*t + ( 200j + 1000)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

# %%
n = 2503

a = np.arange(n)
b = np.arange(n)

x = np.where((a[...,None]*b[None,...] +2 )% n == 0)



plt.xlim([-1,n+1])
plt.ylim([-1,n+1])

plt.xticks(np.arange(0, n+1, n/5))
plt.yticks(np.arange(0, n+1, n/5))

plt.plot(x[0], x[1], '.', markersize=4)

# %%
plt.subplot(2,2,1)

n = 1000

a = np.arange(n)
b = np.arange(n)

x = np.where((a[...,None]*b[None,...] +2 )% n == 0)



plt.xlim([-1,n+1])
plt.ylim([-1,n+1])

plt.xticks(np.arange(0, n+1, n/5))
plt.yticks(np.arange(0, n+1, n/5))

plt.plot(x[0], x[1], '.', markersize=4)

dt = 0.01
t  = np.arange(0,1+dt,dt)

z = 200j*t + (400+1000j)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 100*t + (600+1000j)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 400*t + (900+1000j)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 600*t + (1000+800j)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 800j*t + ( 100 + 1000j)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 900j*t + ( 200 + 1000j)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 200*t + (400j+1000)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 100j*t + (600j+1000)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 400j*t + (900j+1000)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 600j*t + (1000j+800)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 800*t + ( 100j + 1000)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

z = 900*t + ( 200j + 1000)*(1-t)
plt.plot(z.real, z.imag, 'g-',  linewidth=3, alpha=0.25)

plt.subplot(2,2,2)

n = 1500

a = np.arange(n)
b = np.arange(n)

x = np.where((a[...,None]*b[None,...] +2 )% n == 0)



plt.xlim([-1,n+1])
plt.ylim([-1,n+1])

plt.xticks(np.arange(0, n+1, n/5))
plt.yticks(np.arange(0, n+1, n/5))

dt = 0.01
t  = np.arange(0,1+dt,dt)
z  = (n*1.0/2)*(1 + 1j) + (n*1.0/2)*np.exp(2j*np.pi*t)


plt.plot(x[0], x[1], '.', markersize=4)
plt.plot(z.real, z.imag, '-', linewidth=3, alpha=0.25)



plt.subplot(2,2,3)

n = 1000

a = np.arange(n)
b = np.arange(n)

x = np.where((a[...,None]*b[None,...] +2 )% n == 0)



plt.xlim([-1,n+1])
plt.ylim([-1,n+1])

plt.xticks(np.arange(0, n+1, n/5))
plt.yticks(np.arange(0, n+1, n/5))

plt.plot(x[0], x[1], '.', markersize=4)



plt.subplot(2,2,4)

n = 1500

a = np.arange(n)
b = np.arange(n)

x = np.where((a[...,None]*b[None,...] +2 )% n == 0)



plt.xlim([-1,n+1])
plt.ylim([-1,n+1])

plt.xticks(np.arange(0, n+1, n/5))
plt.yticks(np.arange(0, n+1, n/5))




plt.plot(x[0], x[1], '.', markersize=4)

# %%
plt.subplot(2,2,1)

n = 1007

a = np.arange(n)
b = np.arange(n)

x = np.where((a[...,None]*b[None,...] +2 )% n == 0)



plt.xlim([-1,n+1])
plt.ylim([-1,n+1])

#plt.xticks(np.arange(0, n+1, n/5))
#plt.yticks(np.arange(0, n+1, n/5))

plt.xticks(200*np.arange(6))
plt.yticks(200*np.arange(6))

plt.plot(x[0], x[1], '.', markersize=4)



plt.subplot(2,2,2)

n = 1511

a = np.arange(n)
b = np.arange(n)

x = np.where((a[...,None]*b[None,...] +2 )% n == 0)



plt.xlim([-1,n+1])
plt.ylim([-1,n+1])

plt.xticks(300*np.arange(6))
plt.yticks(300*np.arange(6))
#plt.xticks(np.arange(0, n+1, n/5))
#plt.yticks(np.arange(0, n+1, n/5))




plt.plot(x[0], x[1], '.', markersize=4)



plt.subplot(2,2,3)

n = 1003

a = np.arange(n)
b = np.arange(n)

x = np.where((a[...,None]*b[None,...] +2 )% n == 0)



plt.xlim([-1,n+1])
plt.ylim([-1,n+1])

plt.xticks(np.arange(0, n+1, n/5))
plt.yticks(np.arange(0, n+1, n/5))



plt.plot(x[0], x[1], '.', markersize=4)



plt.subplot(2,2,4)

n = 1501

a = np.arange(n)
b = np.arange(n)

x = np.where((a[...,None]*b[None,...] +2 )% n == 0)



plt.xlim([-1,n+1])
plt.ylim([-1,n+1])

plt.xticks(np.arange(0, n+1, n/5))
plt.yticks(np.arange(0, n+1, n/5))




plt.plot(x[0], x[1], '.', markersize=4)
