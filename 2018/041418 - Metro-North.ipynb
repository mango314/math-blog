# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8,6

# %%
np.nan + 1, np.nan * 5, np.nan + np.nan
# Out:
# (nan, nan, nan)

# %%
np.nan * 5
# Out:
# nan

# %%
x = np.array([1.0, -3])
x/0, x**0.5
# Out:
# (array([ inf, -inf]), array([  1.,  nan]))

# %%
x  = pd.Series([1.0])
x/0
# Out:
# 0    inf
# dtype: float64

# %%
x = pd.read_csv("physics/041218-Train.csv")

# %%
x
# Out:
#            Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0          0.000000                0.399597                1.191620
# 1          0.002472                0.344574                1.177261
# 2          0.004944                0.334991                1.220337
# 3          0.007416                0.337387                1.167694
# 4          0.009888                0.311066                1.143768
# 5          0.012360                0.287140                1.119843
# 6          0.014832                0.334991                1.105484
# 7          0.017303                0.291931                1.122238
# 8          0.019775                0.265610                1.158127
# 9          0.022247                0.251251                1.167694
# 10         0.024719                0.267990                1.191620
# 11         0.027191                0.320633                1.153336
# 12         0.029663                0.370880                1.162918
# ...

# %%
x.keys()
# Out:
# Index([u'Time (s)', u'Acceleration x (m/s^2)', u'Acceleration y (m/s^2)',
#        u'Acceleration z (m/s^2)', u'Absolute acceleration (m/s^2)'],
#       dtype='object')

# %%
plt.plot( x['Time (s)'] , x['Acceleration x (m/s^2)'] , '.' , markersize= 1 )

# %%
x['Time (s)'][1:]
# Out:
# 1            0.002472
# 2            0.004944
# 3            0.007416
# 4            0.009888
# 5            0.012360
# 6            0.014832
# 7            0.017303
# 8            0.019775
# 9            0.022247
# 10           0.024719
# 11           0.027191
# 12           0.029663
# 13           0.032135
# 14           0.034607
# 15           0.037079
# 16           0.039551
# 17           0.042023
# 18           0.044495
# 19           0.046967
# 20           0.049438
# 21           0.051910
# 22           0.054382
# 23           0.056854
# 24           0.059326
# 25           0.061798
# 26           0.064270
# 27           0.066742
# 28           0.069214
# 29           0.071655
# 30           0.074127
#              ...
# 464073    1146.547144
# 464074    1146.549616
# 464075    1146.552088
# 464076    1146.554560
# 464077    1146.557031
# 464078    1146.559503
# 464079    1146.561945
# 464080    1146.564417
# 464081    1146.566889
# 464082    1146.569361
# ...

# %%
x['Time (s)'][:-1]
# Out:
# 0            0.000000
# 1            0.002472
# 2            0.004944
# 3            0.007416
# 4            0.009888
# 5            0.012360
# 6            0.014832
# 7            0.017303
# 8            0.019775
# 9            0.022247
# 10           0.024719
# 11           0.027191
# 12           0.029663
# 13           0.032135
# 14           0.034607
# 15           0.037079
# 16           0.039551
# 17           0.042023
# 18           0.044495
# 19           0.046967
# 20           0.049438
# 21           0.051910
# 22           0.054382
# 23           0.056854
# 24           0.059326
# 25           0.061798
# 26           0.064270
# 27           0.066742
# 28           0.069214
# 29           0.071655
#              ...
# 464072    1146.544672
# 464073    1146.547144
# 464074    1146.549616
# 464075    1146.552088
# 464076    1146.554560
# 464077    1146.557031
# 464078    1146.559503
# 464079    1146.561945
# 464080    1146.564417
# 464081    1146.566889
# ...

# %%
0.002472*20
# Out:
# 0.04944
